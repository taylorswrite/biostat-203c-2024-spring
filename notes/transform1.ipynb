# %% [markdown]
# # More data wrangling

# %% [markdown]
# __iClicker:__ Please comment anything about the course.
#
# __iClicker__: Extra office hours beginning next week!
#
# - A. __Monday 7 pm__
# - B. Monday 8 pm
# - C. Wednesday 7 pm
# - D. Wednesday 8 pm
#
#
#
# A lot of things covered in the Week 5 lectures:
#
#
# - Data wrangling with Pandas
#   - Row and column manipulation
#     - indexing with `loc` and `iloc`
#     - `query()`
#     - pivoting - changing rows and columns
#     - `drop()`
#     - `str` attributes
#     - `assign()`
#   - Aggregations
#     - `groupby()`
#     - `agg()` or `aggregate()`
#     - `apply()`
#   - Joins
#     - The `merge()` method
#
# - Visualization
#   - Matplotlib
#   - Seaborn
#   - Plotly
#
# - Databases
#   - `sqlite3`
#   - `DuckDB`
#
# - Web scraping
#   - We used `BeautifulSoup`.
#   - CSS selectors
#   - Some other tools include: `scrapy`, more scalable and has more features. Requires knowledge in OOP.
#   - There are fair amount of webpages involving JavaScript. For example: The pagination through the "next" button from the page
#   https://www.imdb.com/search/title/?title_type=feature&release_date=2023-01-01,2023-12-31&count=100
#   - `selenium` is the package to use in that case.
#
#
# Homework 3 and 4 intensively feature data wrangling, visualization, and some databases.
#
# Homework 5 will be a web scraping homework featuring autograder.
#
#
#
# Let's discuss a bit more about data wrangling pattern.
#
# ## Transformation
#
# In the last lecture, we had an example selecting first ICU stay of each subject:
#
#
#
# ```R
# icustays_subset <- icustays_tble |>
#   # first ICU stay of each unique `subject_id`
#   group_by(subject_id) |>
#   slice_min(intime) |>
#   ungroup() |>
#   show_query() |>
#   print(width = Inf)
# ```

# %%
sql_cmd = """
SELECT
  subject_id,
  hadm_id,
  stay_id,
  first_careunit,
  last_careunit,
  intime,
  outtime,
  los
FROM (
  SELECT
    *,
    RANK() OVER (PARTITION BY subject_id ORDER BY intime) AS visit_num
  FROM icustays
) 
WHERE (visit_num == 1)
"""

# %%
# %%time
import pandas as pd
import sqlite3
with sqlite3.connect("mimiciv.sqlite") as conn:
    df = pd.read_sql_query(sql_cmd, conn)
df
# Out:
# CPU times: user 167 ms, sys: 32.8 ms, total: 200 ms
# Wall time: 208 ms
#        subject_id   hadm_id   stay_id  \
# 0        10000032  29079034  39553978
# 1        10000980  26913865  39765666
# 2        10001217  24597018  37067082
# 3        10001725  25563031  31205490
# 4        10001884  26184834  37510196
# ...           ...       ...       ...
# 50915    19999442  26785317  32336619
# 50916    19999625  25304202  31070865
# 50917    19999828  25744818  36075953
# 50918    19999840  21033226  38978960
# 50919    19999987  23865745  36195440
#
#                                          first_careunit  \
# 0                    Medical Intensive Care Unit (MICU)
# 1                    Medical Intensive Care Unit (MICU)
# 2                   Surgical Intensive Care Unit (SICU)
# 3      Medical/Surgical Intensive Care Unit (MICU/SICU)
# 4                    Medical Intensive Care Unit (MICU)
# ...                                                 ...
# 50915               Surgical Intensive Care Unit (SICU)
# 50916  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 50917                Medical Intensive Care Unit (MICU)
# 50918                               Trauma SICU (TSICU)
# 50919                               Trauma SICU (TSICU)
#
#                                           last_careunit               intime  \
# 0                    Medical Intensive Care Unit (MICU)  2180-07-23 14:00:00
# 1                    Medical Intensive Care Unit (MICU)  2189-06-27 08:42:00
# 2                   Surgical Intensive Care Unit (SICU)  2157-11-20 19:18:02
# 3      Medical/Surgical Intensive Care Unit (MICU/SICU)  2110-04-11 15:52:22
# 4                    Medical Intensive Care Unit (MICU)  2131-01-11 04:20:05
# ...                                                 ...                  ...
# 50915               Surgical Intensive Care Unit (SICU)  2148-11-19 14:23:43
# 50916  Medical/Surgical Intensive Care Unit (MICU/SICU)  2139-10-10 19:18:00
# 50917                Medical Intensive Care Unit (MICU)  2149-01-08 18:12:00
# 50918               Surgical Intensive Care Unit (SICU)  2164-09-12 09:26:28
# 50919                               Trauma SICU (TSICU)  2145-11-02 22:59:00
#
#                    outtime       los
# 0      2180-07-23 23:50:47  0.410266
# 1      2189-06-27 20:38:27  0.497535
# 2      2157-11-21 22:08:00  1.118032
# 3      2110-04-12 23:59:56  1.338588
# 4      2131-01-20 08:27:30  9.171817
# ...                    ...       ...
# 50915  2148-11-26 13:12:15  6.950370
# 50916  2139-10-11 18:21:28  0.960741
# 50917  2149-01-10 13:11:02  1.790995
# 50918  2164-09-17 16:35:15  5.297766
# 50919  2145-11-04 21:29:30  1.937847
#
# [50920 rows x 8 columns]

# %% [markdown]
# We had a new pattern of SQL command, which could not be directly converted to `pandas` commands from what we have learned so far.
#
# The first `SELECT` query run is:
# ```sql
# SELECT
# *,
# RANK() OVER (PARTITION BY subject_id ORDER BY intime) AS visit_num
# FROM icustays
# ```
# It adds a new column named `visit_num` corresponding to the order of visit within `subject_id`. The `OVER` keyword indicates the use of [window function](https://database.guide/understanding-window-functions-in-sql/). What it does may seem similar to general aggregations, but the catch here is that the number of rows is retained.
#
# - `PARTITION BY` is similar to `GROUP BY`
# - `ORDER BY` gives order within the group
# - `RANK()` function computes the rank within the partition based on the ordering defined.

# %% [markdown]
# Actually, we can achieve the same thing using the function `transform()`.

# %% [markdown]
# Let's read the `icustays.csv.gz` file as a data frame.

# %%
icustays = pd.read_csv("~/mimic/icu/icustays.csv.gz")

# %%
icustays
# Out:
#        subject_id   hadm_id   stay_id  \
# 0        10000032  29079034  39553978
# 1        10000980  26913865  39765666
# 2        10001217  24597018  37067082
# 3        10001217  27703517  34592300
# 4        10001725  25563031  31205490
# ...           ...       ...       ...
# 73176    19999442  26785317  32336619
# 73177    19999625  25304202  31070865
# 73178    19999828  25744818  36075953
# 73179    19999840  21033226  38978960
# 73180    19999987  23865745  36195440
#
#                                          first_careunit  \
# 0                    Medical Intensive Care Unit (MICU)
# 1                    Medical Intensive Care Unit (MICU)
# 2                   Surgical Intensive Care Unit (SICU)
# 3                   Surgical Intensive Care Unit (SICU)
# 4      Medical/Surgical Intensive Care Unit (MICU/SICU)
# ...                                                 ...
# 73176               Surgical Intensive Care Unit (SICU)
# 73177  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 73178                Medical Intensive Care Unit (MICU)
# 73179                               Trauma SICU (TSICU)
# 73180                               Trauma SICU (TSICU)
#
#                                           last_careunit               intime  \
# 0                    Medical Intensive Care Unit (MICU)  2180-07-23 14:00:00
# 1                    Medical Intensive Care Unit (MICU)  2189-06-27 08:42:00
# 2                   Surgical Intensive Care Unit (SICU)  2157-11-20 19:18:02
# 3                   Surgical Intensive Care Unit (SICU)  2157-12-19 15:42:24
# 4      Medical/Surgical Intensive Care Unit (MICU/SICU)  2110-04-11 15:52:22
# ...                                                 ...                  ...
# 73176               Surgical Intensive Care Unit (SICU)  2148-11-19 14:23:43
# 73177  Medical/Surgical Intensive Care Unit (MICU/SICU)  2139-10-10 19:18:00
# 73178                Medical Intensive Care Unit (MICU)  2149-01-08 18:12:00
# 73179               Surgical Intensive Care Unit (SICU)  2164-09-12 09:26:28
# 73180                               Trauma SICU (TSICU)  2145-11-02 22:59:00
#
#                    outtime       los
# 0      2180-07-23 23:50:47  0.410266
# 1      2189-06-27 20:38:27  0.497535
# 2      2157-11-21 22:08:00  1.118032
# 3      2157-12-20 14:27:41  0.948113
# 4      2110-04-12 23:59:56  1.338588
# ...                    ...       ...
# 73176  2148-11-26 13:12:15  6.950370
# 73177  2139-10-11 18:21:28  0.960741
# 73178  2149-01-10 13:11:02  1.790995
# 73179  2164-09-17 16:35:15  5.297766
# 73180  2145-11-04 21:29:30  1.937847
#
# [73181 rows x 8 columns]

# %% [markdown]
# The `transform()` applies the function to each column of `DataFrame` or `Series`. The returned value has the same size as the original data.

# %%
# %%time
icustays["visitnum"] = icustays.groupby("subject_id")["intime"].transform("rank")
# Out:
# CPU times: user 77.9 ms, sys: 15.3 ms, total: 93.2 ms
# Wall time: 112 ms

# %%
icustays["visitnum"] = icustays.groupby("subject_id")["intime"].transform("rank")

# %%
icustays
# Out:
#        subject_id   hadm_id   stay_id  \
# 0        10000032  29079034  39553978
# 1        10000980  26913865  39765666
# 2        10001217  24597018  37067082
# 3        10001217  27703517  34592300
# 4        10001725  25563031  31205490
# ...           ...       ...       ...
# 73176    19999442  26785317  32336619
# 73177    19999625  25304202  31070865
# 73178    19999828  25744818  36075953
# 73179    19999840  21033226  38978960
# 73180    19999987  23865745  36195440
#
#                                          first_careunit  \
# 0                    Medical Intensive Care Unit (MICU)
# 1                    Medical Intensive Care Unit (MICU)
# 2                   Surgical Intensive Care Unit (SICU)
# 3                   Surgical Intensive Care Unit (SICU)
# 4      Medical/Surgical Intensive Care Unit (MICU/SICU)
# ...                                                 ...
# 73176               Surgical Intensive Care Unit (SICU)
# 73177  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 73178                Medical Intensive Care Unit (MICU)
# 73179                               Trauma SICU (TSICU)
# 73180                               Trauma SICU (TSICU)
#
#                                           last_careunit               intime  \
# 0                    Medical Intensive Care Unit (MICU)  2180-07-23 14:00:00
# 1                    Medical Intensive Care Unit (MICU)  2189-06-27 08:42:00
# 2                   Surgical Intensive Care Unit (SICU)  2157-11-20 19:18:02
# 3                   Surgical Intensive Care Unit (SICU)  2157-12-19 15:42:24
# 4      Medical/Surgical Intensive Care Unit (MICU/SICU)  2110-04-11 15:52:22
# ...                                                 ...                  ...
# 73176               Surgical Intensive Care Unit (SICU)  2148-11-19 14:23:43
# 73177  Medical/Surgical Intensive Care Unit (MICU/SICU)  2139-10-10 19:18:00
# 73178                Medical Intensive Care Unit (MICU)  2149-01-08 18:12:00
# 73179               Surgical Intensive Care Unit (SICU)  2164-09-12 09:26:28
# 73180                               Trauma SICU (TSICU)  2145-11-02 22:59:00
#
#                    outtime       los  visitnum
# 0      2180-07-23 23:50:47  0.410266       1.0
# 1      2189-06-27 20:38:27  0.497535       1.0
# 2      2157-11-21 22:08:00  1.118032       1.0
# 3      2157-12-20 14:27:41  0.948113       2.0
# 4      2110-04-12 23:59:56  1.338588       1.0
# ...                    ...       ...       ...
# 73176  2148-11-26 13:12:15  6.950370       1.0
# 73177  2139-10-11 18:21:28  0.960741       1.0
# 73178  2149-01-10 13:11:02  1.790995       1.0
# 73179  2164-09-17 16:35:15  5.297766       1.0
# 73180  2145-11-04 21:29:30  1.937847       1.0
#
# [73181 rows x 9 columns]

# %% [markdown]
# __Exercise__: What pandas command would result in the same `50920 × 8` `DataFrame` as in the previous example?

# %%
# %%timeit
icustays.query("visitnum == 1")#.drop(columns="visitnum")
# Out:
# 2.29 ms ± 108 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
icustays[icustays["visitnum"] == 1]#.drop(columns="visitnum")
# Out:
# 1.94 ms ± 62.8 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# What you might have noticed is that there are more than one ways to select the minimum value within each group. The approach we just have used is flexible in that we can select `n` samples from each group.

# %%
icustays.groupby("subject_id")["intime"].transform(
    lambda x : x.rank(method="average"))
# Out:
# 0        1.0
# 1        1.0
# 2        1.0
# 3        2.0
# 4        1.0
#         ...
# 73176    1.0
# 73177    1.0
# 73178    1.0
# 73179    1.0
# 73180    1.0
# Name: intime, Length: 73181, dtype: float64

# %% [markdown]
# In fact, `rank` within group is used a lot, so there is a dedicated `rank()` method for it.
# It lets you control the behavior on ties (`average` is the default, `min`, `max`, `first`, `dense` available).
#
# In what other scenarios is `transform()` useful?

# %% [markdown]
# cumsum, diff, etc.

# %%
icustays.groupby("subject_id")["intime"].transform(
    lambda x : x.rank(method="max"))
# Out:
# 0        1.0
# 1        1.0
# 2        1.0
# 3        2.0
# 4        1.0
#         ...
# 73176    1.0
# 73177    1.0
# 73178    1.0
# 73179    1.0
# 73180    1.0
# Name: intime, Length: 73181, dtype: float64

# %%
icustays.groupby("subject_id")["intime"].rank(method="max")
# Out:
# 0        1.0
# 1        1.0
# 2        1.0
# 3        2.0
# 4        1.0
#         ...
# 73176    1.0
# 73177    1.0
# 73178    1.0
# 73179    1.0
# 73180    1.0
# Name: intime, Length: 73181, dtype: float64

# %%
icustays.groupby("subject_id")["los"].transform(
    lambda x : (x - x.mean())/x.std())
# Out:
# 0             NaN
# 1             NaN
# 2        0.707107
# 3       -0.707107
# 4             NaN
#            ...
# 73176         NaN
# 73177         NaN
# 73178         NaN
# 73179         NaN
# 73180         NaN
# Name: los, Length: 73181, dtype: float64

# %% [markdown]
# __Problem.__ Select rows of the data frame corresponding to the last ICU visit of each subject.

# %%
icustays["visitnum"] = icustays.groupby("subject_id")["intime"].transform("rank")
icustays["visitcount"] = icustays.groupby("subject_id")["intime"].transform("count")

# %%
icustays.query("visitnum == visitcount")
# Out:
#        subject_id   hadm_id   stay_id  \
# 0        10000032  29079034  39553978
# 1        10000980  26913865  39765666
# 3        10001217  27703517  34592300
# 4        10001725  25563031  31205490
# 5        10001884  26184834  37510196
# ...           ...       ...       ...
# 73176    19999442  26785317  32336619
# 73177    19999625  25304202  31070865
# 73178    19999828  25744818  36075953
# 73179    19999840  21033226  38978960
# 73180    19999987  23865745  36195440
#
#                                          first_careunit  \
# 0                    Medical Intensive Care Unit (MICU)
# 1                    Medical Intensive Care Unit (MICU)
# 3                   Surgical Intensive Care Unit (SICU)
# 4      Medical/Surgical Intensive Care Unit (MICU/SICU)
# 5                    Medical Intensive Care Unit (MICU)
# ...                                                 ...
# 73176               Surgical Intensive Care Unit (SICU)
# 73177  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 73178                Medical Intensive Care Unit (MICU)
# 73179                               Trauma SICU (TSICU)
# 73180                               Trauma SICU (TSICU)
#
#                                           last_careunit               intime  \
# 0                    Medical Intensive Care Unit (MICU)  2180-07-23 14:00:00
# 1                    Medical Intensive Care Unit (MICU)  2189-06-27 08:42:00
# 3                   Surgical Intensive Care Unit (SICU)  2157-12-19 15:42:24
# 4      Medical/Surgical Intensive Care Unit (MICU/SICU)  2110-04-11 15:52:22
# 5                    Medical Intensive Care Unit (MICU)  2131-01-11 04:20:05
# ...                                                 ...                  ...
# 73176               Surgical Intensive Care Unit (SICU)  2148-11-19 14:23:43
# 73177  Medical/Surgical Intensive Care Unit (MICU/SICU)  2139-10-10 19:18:00
# 73178                Medical Intensive Care Unit (MICU)  2149-01-08 18:12:00
# 73179               Surgical Intensive Care Unit (SICU)  2164-09-12 09:26:28
# 73180                               Trauma SICU (TSICU)  2145-11-02 22:59:00
#
#                    outtime       los  visitnum  visitcount
# 0      2180-07-23 23:50:47  0.410266       1.0           1
# 1      2189-06-27 20:38:27  0.497535       1.0           1
# 3      2157-12-20 14:27:41  0.948113       2.0           2
# 4      2110-04-12 23:59:56  1.338588       1.0           1
# 5      2131-01-20 08:27:30  9.171817       1.0           1
# ...                    ...       ...       ...         ...
# 73176  2148-11-26 13:12:15  6.950370       1.0           1
# 73177  2139-10-11 18:21:28  0.960741       1.0           1
# 73178  2149-01-10 13:11:02  1.790995       1.0           1
# 73179  2164-09-17 16:35:15  5.297766       1.0           1
# 73180  2145-11-04 21:29:30  1.937847       1.0           1
#
# [50920 rows x 10 columns]

# %% [markdown]
# When to use `transform()`, `agg()`, and `apply()`?

# %% [markdown]
# - `transform()` applies a function to each column, and its output must have (or be broadcasted to) the same size as the input
# - `agg()` applies a function to each column, and its output must be one number.
# - `apply()` is the most flexible. The function applied may involve multiple columns. However, if something can be done using `agg()` and `transform()`, they will be faster.

# %% [markdown]
# ## Filtrations

# %% [markdown]
# Here is another approach to get the first hospital visit of each subject:

# %%
# %%time
(icustays.sort_values(["intime"]).groupby("subject_id")
 .nth(0).sort_values(["subject_id"])
)
# Out:
# CPU times: user 68.8 ms, sys: 4.74 ms, total: 73.5 ms
# Wall time: 76 ms
#        subject_id   hadm_id   stay_id  \
# 0        10000032  29079034  39553978
# 1        10000980  26913865  39765666
# 2        10001217  24597018  37067082
# 4        10001725  25563031  31205490
# 5        10001884  26184834  37510196
# ...           ...       ...       ...
# 73176    19999442  26785317  32336619
# 73177    19999625  25304202  31070865
# 73178    19999828  25744818  36075953
# 73179    19999840  21033226  38978960
# 73180    19999987  23865745  36195440
#
#                                          first_careunit  \
# 0                    Medical Intensive Care Unit (MICU)
# 1                    Medical Intensive Care Unit (MICU)
# 2                   Surgical Intensive Care Unit (SICU)
# 4      Medical/Surgical Intensive Care Unit (MICU/SICU)
# 5                    Medical Intensive Care Unit (MICU)
# ...                                                 ...
# 73176               Surgical Intensive Care Unit (SICU)
# 73177  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 73178                Medical Intensive Care Unit (MICU)
# 73179                               Trauma SICU (TSICU)
# 73180                               Trauma SICU (TSICU)
#
#                                           last_careunit               intime  \
# 0                    Medical Intensive Care Unit (MICU)  2180-07-23 14:00:00
# 1                    Medical Intensive Care Unit (MICU)  2189-06-27 08:42:00
# 2                   Surgical Intensive Care Unit (SICU)  2157-11-20 19:18:02
# 4      Medical/Surgical Intensive Care Unit (MICU/SICU)  2110-04-11 15:52:22
# 5                    Medical Intensive Care Unit (MICU)  2131-01-11 04:20:05
# ...                                                 ...                  ...
# 73176               Surgical Intensive Care Unit (SICU)  2148-11-19 14:23:43
# 73177  Medical/Surgical Intensive Care Unit (MICU/SICU)  2139-10-10 19:18:00
# 73178                Medical Intensive Care Unit (MICU)  2149-01-08 18:12:00
# 73179               Surgical Intensive Care Unit (SICU)  2164-09-12 09:26:28
# 73180                               Trauma SICU (TSICU)  2145-11-02 22:59:00
#
#                    outtime       los  visitnum  visitcount
# 0      2180-07-23 23:50:47  0.410266       1.0           1
# 1      2189-06-27 20:38:27  0.497535       1.0           1
# 2      2157-11-21 22:08:00  1.118032       1.0           2
# 4      2110-04-12 23:59:56  1.338588       1.0           1
# 5      2131-01-20 08:27:30  9.171817       1.0           1
# ...                    ...       ...       ...         ...
# 73176  2148-11-26 13:12:15  6.950370       1.0           1
# 73177  2139-10-11 18:21:28  0.960741       1.0           1
# 73178  2149-01-10 13:11:02  1.790995       1.0           1
# 73179  2164-09-17 16:35:15  5.297766       1.0           1
# 73180  2145-11-04 21:29:30  1.937847       1.0           1
#
# [50920 rows x 10 columns]

# %% [markdown]
# For the second visits:

# %%
(icustays.sort_values(["intime"]).groupby("subject_id")
 .nth(1).sort_values(["subject_id"]))
# Out:
#        subject_id   hadm_id   stay_id  \
# 3        10001217  27703517  34592300
# 9        10002155  28994087  31090461
# 14       10002428  28662225  38875437
# 20       10002930  25922998  35629889
# 24       10003400  23559586  34577403
# ...           ...       ...       ...
# 73155    19997473  27787494  32134105
# 73165    19998330  24492004  32641669
# 73166    19998591  24349193  31144045
# 73170    19998878  26489544  34403689
# 73173    19999287  20175828  35165301
#
#                                          first_careunit  \
# 3                   Surgical Intensive Care Unit (SICU)
# 9      Medical/Surgical Intensive Care Unit (MICU/SICU)
# 14                   Medical Intensive Care Unit (MICU)
# 20     Medical/Surgical Intensive Care Unit (MICU/SICU)
# 24     Medical/Surgical Intensive Care Unit (MICU/SICU)
# ...                                                 ...
# 73155                          Coronary Care Unit (CCU)
# 73165  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 73166                Medical Intensive Care Unit (MICU)
# 73170  Medical/Surgical Intensive Care Unit (MICU/SICU)
# 73173  Medical/Surgical Intensive Care Unit (MICU/SICU)
#
#                                           last_careunit               intime  \
# 3                   Surgical Intensive Care Unit (SICU)  2157-12-19 15:42:24
# 9      Medical/Surgical Intensive Care Unit (MICU/SICU)  2130-09-24 00:50:00
# 14                   Medical Intensive Care Unit (MICU)  2156-04-19 18:11:19
# 20     Medical/Surgical Intensive Care Unit (MICU/SICU)  2198-04-17 21:24:00
# 24     Medical/Surgical Intensive Care Unit (MICU/SICU)  2137-08-10 19:54:51
# ...                                                 ...                  ...
# 73155                          Coronary Care Unit (CCU)  2173-09-17 15:07:55
# 73165  Medical/Surgical Intensive Care Unit (MICU/SICU)  2178-10-01 08:51:00
# 73166                Medical Intensive Care Unit (MICU)  2185-07-16 18:48:18
# 73170  Medical/Surgical Intensive Care Unit (MICU/SICU)  2132-09-30 21:55:00
# 73173  Medical/Surgical Intensive Care Unit (MICU/SICU)  2197-08-04 00:02:00
#
#                    outtime       los  visitnum  visitcount
# 3      2157-12-20 14:27:41  0.948113       2.0           2
# 9      2130-09-27 22:13:41  3.891447       2.0           3
# 14     2156-04-26 18:58:41  7.032894       2.0           4
# 20     2198-04-18 13:41:43  0.678970       2.0           2
# 24     2137-08-13 17:54:54  2.916701       2.0           3
# ...                    ...       ...       ...         ...
# 73155  2173-09-22 06:39:09  4.646690       2.0           2
# 73165  2178-10-03 23:25:08  2.607037       2.0           6
# 73166  2185-07-26 18:27:01  9.985220       2.0           2
# 73170  2132-10-01 15:43:11  0.741794       2.0           2
# 73173  2197-08-08 16:58:17  4.705752       2.0           2
#
# [12448 rows x 10 columns]

# %% [markdown]
# ## Another package worth mentioning: `polars`

# %% [markdown]
# Polars is another package worth mentioning. Some of the `pandas` core developers are working on it to create a more performant python-based `DataFrame`. It automatically use multiple cores on your computer, just like `DuckDB` does. It takes advantage of `arrow` memory representation, resulting in efficient and cross-platform data layout. The implementation is backed by the programming language `Rust`.
#
# Perhaps `polars` and `DuckDB` are two of the hottest topic for single-machine data analytics today.
#
# - `DuckDB` is heavily based on SQL queries.
# - `polars` is more of a Python programming tool.
#
# DuckDB people maintain benchmark of the performance of queries within a single machine:
# https://duckdb.org/2023/11/03/db-benchmark-update.html
#
#
# Syntax of `polars` highly resembles that of `pandas`, with some minor changes in selection and how to build user-defined queries. It is possible to optimize query and perform lazy evaluation.
#
#
#
# From [their documentation](https://docs.pola.rs/):
# Key features include:
# - __Fast__: Written from scratch in Rust, designed close to the machine and without external dependencies.
# - __I/O__: First class support for all common data storage layers: local, cloud storage & databases.
# - __Intuitive API__: Write your queries the way they were intended. Polars, internally, will determine the most efficient way to execute using its query optimizer.
# - __Out of Core__: The streaming API allows you to process your results without requiring all your data to be in memory at the same time
# - __Parallel__: Utilises the power of your machine by dividing the workload among the available CPU cores without any additional configuration.
# - __Vectorized Query Engine__: Using Apache Arrow, a columnar data format, to process your queries in a vectorized manner and SIMD to optimize CPU usage.
#
#
# Philosophy:
# The goal of Polars is to provide a lightning fast DataFrame library that:
#
# - Utilizes all available cores on your machine.
# - Optimizes queries to reduce unneeded work/memory allocations.
# - Handles datasets much larger than your available RAM.
# - A consistent and predictable API.
# - Adheres to a strict schema (data-types should be known before running the query).
# - Polars is written in Rust which gives it C/C++ performance and allows it to fully control performance critical parts in a query engine.

# %%
import polars as pl
from datetime import datetime

df = pl.DataFrame(
    {
        "integer": [1, 2, 3],
        "date": [
            datetime(2025, 1, 1),
            datetime(2025, 1, 2),
            datetime(2025, 1, 3),
        ],
        "float": [4.0, 5.0, 6.0],
        "string": ["a", "b", "c"],
    }
)

print(df)
# Out:
# shape: (3, 4)
# ┌─────────┬─────────────────────┬───────┬────────┐
# │ integer ┆ date                ┆ float ┆ string │
# │ ---     ┆ ---                 ┆ ---   ┆ ---    │
# │ i64     ┆ datetime[μs]        ┆ f64   ┆ str    │
# ╞═════════╪═════════════════════╪═══════╪════════╡
# │ 1       ┆ 2025-01-01 00:00:00 ┆ 4.0   ┆ a      │
# │ 2       ┆ 2025-01-02 00:00:00 ┆ 5.0   ┆ b      │
# │ 3       ┆ 2025-01-03 00:00:00 ┆ 6.0   ┆ c      │
# └─────────┴─────────────────────┴───────┴────────┘

# %% [markdown]
# I encourage you to try this package out for Homework 4 -- this is not enforced, though.
#
# Some example:

# %%
icustays_pl = pl.read_csv("~/mimic/icu/icustays.csv.gz")

# %% [markdown]
# Lazy evaluation is not available for `csv.gz` yet.

# %%
icustays_pl.head(10)
# Out:
# shape: (10, 8)
# ┌────────────┬──────────┬──────────┬─────────────┬────────────┬────────────┬────────────┬──────────┐
# │ subject_id ┆ hadm_id  ┆ stay_id  ┆ first_careu ┆ last_careu ┆ intime     ┆ outtime    ┆ los      │
# │ ---        ┆ ---      ┆ ---      ┆ nit         ┆ nit        ┆ ---        ┆ ---        ┆ ---      │
# │ i64        ┆ i64      ┆ i64      ┆ ---         ┆ ---        ┆ str        ┆ str        ┆ f64      │
# │            ┆          ┆          ┆ str         ┆ str        ┆            ┆            ┆          │
# ╞════════════╪══════════╪══════════╪═════════════╪════════════╪════════════╪════════════╪══════════╡
# │ 10000032   ┆ 29079034 ┆ 39553978 ┆ Medical     ┆ Medical    ┆ 2180-07-23 ┆ 2180-07-23 ┆ 0.410266 │
# │            ┆          ┆          ┆ Intensive   ┆ Intensive  ┆ 14:00:00   ┆ 23:50:47   ┆          │
# │            ┆          ┆          ┆ Care Unit   ┆ Care Unit  ┆            ┆            ┆          │
# │            ┆          ┆          ┆ (M…         ┆ (M…        ┆            ┆            ┆          │
# │ 10000980   ┆ 26913865 ┆ 39765666 ┆ Medical     ┆ Medical    ┆ 2189-06-27 ┆ 2189-06-27 ┆ 0.497535 │
# │            ┆          ┆          ┆ Intensive   ┆ Intensive  ┆ 08:42:00   ┆ 20:38:27   ┆          │
# │            ┆          ┆          ┆ Care Unit   ┆ Care Unit  ┆            ┆            ┆          │
# │            ┆          ┆          ┆ (M…         ┆ (M…        ┆            ┆            ┆          │
# │ 10001217   ┆ 24597018 ┆ 37067082 ┆ Surgical    ┆ Surgical   ┆ 2157-11-20 ┆ 2157-11-21 ┆ 1.118032 │
# │            ┆          ┆          ┆ Intensive   ┆ Intensive  ┆ 19:18:02   ┆ 22:08:00   ┆          │
# │            ┆          ┆          ┆ Care Unit   ┆ Care Unit  ┆            ┆            ┆          │
# │            ┆          ┆          ┆ (…          ┆ (…         ┆            ┆            ┆          │
# │ 10001217   ┆ 27703517 ┆ 34592300 ┆ Surgical    ┆ Surgical   ┆ 2157-12-19 ┆ 2157-12-20 ┆ 0.948113 │
# │            ┆          ┆          ┆ Intensive   ┆ Intensive  ┆ 15:42:24   ┆ 14:27:41   ┆          │
# │            ┆          ┆          ┆ Care Unit   ┆ Care Unit  ┆            ┆            ┆          │
# │            ┆          ┆          ┆ (…          ┆ (…         ┆            ┆            ┆          │
# │ 10001725   ┆ 25563031 ┆ 31205490 ┆ Medical/Sur ┆ Medical/Su ┆ 2110-04-11 ┆ 2110-04-12 ┆ 1.338588 │
# │            ┆          ┆          ┆ gical       ┆ rgical     ┆ 15:52:22   ┆ 23:59:56   ┆          │
# │            ┆          ┆          ┆ Intensive   ┆ Intensive  ┆            ┆            ┆          │
# │            ┆          ┆          ┆ Car…        ┆ Car…       ┆            ┆            ┆          │
# │ 10001884   ┆ 26184834 ┆ 37510196 ┆ Medical     ┆ Medical    ┆ 2131-01-11 ┆ 2131-01-20 ┆ 9.171817 │
# │            ┆          ┆          ┆ Intensive   ┆ Intensive  ┆ 04:20:05   ┆ 08:27:30   ┆          │
# │            ┆          ┆          ┆ Care Unit   ┆ Care Unit  ┆            ┆            ┆          │
# │            ┆          ┆          ┆ (M…         ┆ (M…        ┆            ┆            ┆          │
# │ 10002013   ┆ 23581541 ┆ 39060235 ┆ Cardiac     ┆ Cardiac    ┆ 2160-05-18 ┆ 2160-05-19 ┆ 1.314352 │
# │            ┆          ┆          ┆ Vascular    ┆ Vascular   ┆ 10:00:53   ┆ 17:33:33   ┆          │
# │            ┆          ┆          ┆ Intensive   ┆ Intensive  ┆            ┆            ┆          │
# │            ┆          ┆          ┆ Car…        ┆ Car…       ┆            ┆            ┆          │
# │ 10002155   ┆ 20345487 ┆ 32358465 ┆ Medical     ┆ Medical    ┆ 2131-03-09 ┆ 2131-03-10 ┆ 0.858576 │
# │            ┆          ┆          ┆ Intensive   ┆ Intensive  ┆ 21:33:00   ┆ 18:09:21   ┆          │
# │            ┆          ┆          ┆ Care Unit   ┆ Care Unit  ┆            ┆            ┆          │
# │            ┆          ┆          ┆ (M…         ┆ (M…        ┆            ┆            ┆          │
# │ 10002155   ┆ 23822395 ┆ 33685454 ┆ Coronary    ┆ Coronary   ┆ 2129-08-04 ┆ 2129-08-10 ┆ 6.178912 │
# │            ┆          ┆          ┆ Care Unit   ┆ Care Unit  ┆ 12:45:00   ┆ 17:02:38   ┆          │
# │            ┆          ┆          ┆ (CCU)       ┆ (CCU)      ┆            ┆            ┆          │
# │ 10002155   ┆ 28994087 ┆ 31090461 ┆ Medical/Sur ┆ Medical/Su ┆ 2130-09-24 ┆ 2130-09-27 ┆ 3.891447 │
# │            ┆          ┆          ┆ gical       ┆ rgical     ┆ 00:50:00   ┆ 22:13:41   ┆          │
# │            ┆          ┆          ┆ Intensive   ┆ Intensive  ┆            ┆            ┆          │
# │            ┆          ┆          ┆ Car…        ┆ Car…       ┆            ┆            ┆          │
# └────────────┴──────────┴──────────┴─────────────┴────────────┴────────────┴────────────┴──────────┘

# %%
icustays_pl.group_by("subject_id").len() # Note that the result changes each run.
# Out:
# shape: (50_920, 2)
# ┌────────────┬─────┐
# │ subject_id ┆ len │
# │ ---        ┆ --- │
# │ i64        ┆ u32 │
# ╞════════════╪═════╡
# │ 10000032   ┆ 1   │
# │ 10000980   ┆ 1   │
# │ 10001217   ┆ 2   │
# │ 10001725   ┆ 1   │
# │ 10001884   ┆ 1   │
# │ …          ┆ …   │
# │ 19999442   ┆ 1   │
# │ 19999625   ┆ 1   │
# │ 19999828   ┆ 1   │
# │ 19999840   ┆ 1   │
# │ 19999987   ┆ 1   │
# └────────────┴─────┘

# %%
pl.__version__
# Out:
# '0.20.25'

# %% [markdown]
# A simple aggregation:

# %%
# %%time
icustays_pl.group_by("subject_id").len().sort("subject_id")
# Out:
# CPU times: user 8.16 ms, sys: 7.71 ms, total: 15.9 ms
# Wall time: 6.14 ms
# shape: (50_920, 2)
# ┌────────────┬─────┐
# │ subject_id ┆ len │
# │ ---        ┆ --- │
# │ i64        ┆ u32 │
# ╞════════════╪═════╡
# │ 10000032   ┆ 1   │
# │ 10000980   ┆ 1   │
# │ 10001217   ┆ 2   │
# │ 10001725   ┆ 1   │
# │ 10001884   ┆ 1   │
# │ …          ┆ …   │
# │ 19999442   ┆ 1   │
# │ 19999625   ┆ 1   │
# │ 19999828   ┆ 1   │
# │ 19999840   ┆ 1   │
# │ 19999987   ┆ 1   │
# └────────────┴─────┘

# %%
icustays_pl
# Out:
# shape: (73_181, 8)
# ┌────────────┬──────────┬──────────┬─────────────┬────────────┬────────────┬────────────┬──────────┐
# │ subject_id ┆ hadm_id  ┆ stay_id  ┆ first_careu ┆ last_careu ┆ intime     ┆ outtime    ┆ los      │
# │ ---        ┆ ---      ┆ ---      ┆ nit         ┆ nit        ┆ ---        ┆ ---        ┆ ---      │
# │ i64        ┆ i64      ┆ i64      ┆ ---         ┆ ---        ┆ str        ┆ str        ┆ f64      │
# │            ┆          ┆          ┆ str         ┆ str        ┆            ┆            ┆          │
# ╞════════════╪══════════╪══════════╪═════════════╪════════════╪════════════╪════════════╪══════════╡
# │ 10000032   ┆ 29079034 ┆ 39553978 ┆ Medical     ┆ Medical    ┆ 2180-07-23 ┆ 2180-07-23 ┆ 0.410266 │
# │            ┆          ┆          ┆ Intensive   ┆ Intensive  ┆ 14:00:00   ┆ 23:50:47   ┆          │
# │            ┆          ┆          ┆ Care Unit   ┆ Care Unit  ┆            ┆            ┆          │
# │            ┆          ┆          ┆ (M…         ┆ (M…        ┆            ┆            ┆          │
# │ 10000980   ┆ 26913865 ┆ 39765666 ┆ Medical     ┆ Medical    ┆ 2189-06-27 ┆ 2189-06-27 ┆ 0.497535 │
# │            ┆          ┆          ┆ Intensive   ┆ Intensive  ┆ 08:42:00   ┆ 20:38:27   ┆          │
# │            ┆          ┆          ┆ Care Unit   ┆ Care Unit  ┆            ┆            ┆          │
# │            ┆          ┆          ┆ (M…         ┆ (M…        ┆            ┆            ┆          │
# │ 10001217   ┆ 24597018 ┆ 37067082 ┆ Surgical    ┆ Surgical   ┆ 2157-11-20 ┆ 2157-11-21 ┆ 1.118032 │
# │            ┆          ┆          ┆ Intensive   ┆ Intensive  ┆ 19:18:02   ┆ 22:08:00   ┆          │
# │            ┆          ┆          ┆ Care Unit   ┆ Care Unit  ┆            ┆            ┆          │
# │            ┆          ┆          ┆ (…          ┆ (…         ┆            ┆            ┆          │
# │ 10001217   ┆ 27703517 ┆ 34592300 ┆ Surgical    ┆ Surgical   ┆ 2157-12-19 ┆ 2157-12-20 ┆ 0.948113 │
# │            ┆          ┆          ┆ Intensive   ┆ Intensive  ┆ 15:42:24   ┆ 14:27:41   ┆          │
# │            ┆          ┆          ┆ Care Unit   ┆ Care Unit  ┆            ┆            ┆          │
# │            ┆          ┆          ┆ (…          ┆ (…         ┆            ┆            ┆          │
# │ 10001725   ┆ 25563031 ┆ 31205490 ┆ Medical/Sur ┆ Medical/Su ┆ 2110-04-11 ┆ 2110-04-12 ┆ 1.338588 │
# │            ┆          ┆          ┆ gical       ┆ rgical     ┆ 15:52:22   ┆ 23:59:56   ┆          │
# │            ┆          ┆          ┆ Intensive   ┆ Intensive  ┆            ┆            ┆          │
# │            ┆          ┆          ┆ Car…        ┆ Car…       ┆            ┆            ┆          │
# │ …          ┆ …        ┆ …        ┆ …           ┆ …          ┆ …          ┆ …          ┆ …        │
# │ 19999442   ┆ 26785317 ┆ 32336619 ┆ Surgical    ┆ Surgical   ┆ 2148-11-19 ┆ 2148-11-26 ┆ 6.95037  │
# │            ┆          ┆          ┆ Intensive   ┆ Intensive  ┆ 14:23:43   ┆ 13:12:15   ┆          │
# │            ┆          ┆          ┆ Care Unit   ┆ Care Unit  ┆            ┆            ┆          │
# │            ┆          ┆          ┆ (…          ┆ (…         ┆            ┆            ┆          │
# │ 19999625   ┆ 25304202 ┆ 31070865 ┆ Medical/Sur ┆ Medical/Su ┆ 2139-10-10 ┆ 2139-10-11 ┆ 0.960741 │
# │            ┆          ┆          ┆ gical       ┆ rgical     ┆ 19:18:00   ┆ 18:21:28   ┆          │
# │            ┆          ┆          ┆ Intensive   ┆ Intensive  ┆            ┆            ┆          │
# │            ┆          ┆          ┆ Car…        ┆ Car…       ┆            ┆            ┆          │
# │ 19999828   ┆ 25744818 ┆ 36075953 ┆ Medical     ┆ Medical    ┆ 2149-01-08 ┆ 2149-01-10 ┆ 1.790995 │
# │            ┆          ┆          ┆ Intensive   ┆ Intensive  ┆ 18:12:00   ┆ 13:11:02   ┆          │
# │            ┆          ┆          ┆ Care Unit   ┆ Care Unit  ┆            ┆            ┆          │
# │            ┆          ┆          ┆ (M…         ┆ (M…        ┆            ┆            ┆          │
# │ 19999840   ┆ 21033226 ┆ 38978960 ┆ Trauma SICU ┆ Surgical   ┆ 2164-09-12 ┆ 2164-09-17 ┆ 5.297766 │
# │            ┆          ┆          ┆ (TSICU)     ┆ Intensive  ┆ 09:26:28   ┆ 16:35:15   ┆          │
# │            ┆          ┆          ┆             ┆ Care Unit  ┆            ┆            ┆          │
# │            ┆          ┆          ┆             ┆ (…         ┆            ┆            ┆          │
# │ 19999987   ┆ 23865745 ┆ 36195440 ┆ Trauma SICU ┆ Trauma     ┆ 2145-11-02 ┆ 2145-11-04 ┆ 1.937847 │
# │            ┆          ┆          ┆ (TSICU)     ┆ SICU       ┆ 22:59:00   ┆ 21:29:30   ┆          │
# │            ┆          ┆          ┆             ┆ (TSICU)    ┆            ┆            ┆          │
# └────────────┴──────────┴──────────┴─────────────┴────────────┴────────────┴────────────┴──────────┘

# %%
# %%time
(icustays_pl.sort(["intime"]).group_by("subject_id")
 .first().sort("subject_id")
)
# Out:
# CPU times: user 56.4 ms, sys: 11.3 ms, total: 67.7 ms
# Wall time: 23.2 ms
# shape: (50_920, 8)
# ┌────────────┬──────────┬──────────┬─────────────┬────────────┬────────────┬────────────┬──────────┐
# │ subject_id ┆ hadm_id  ┆ stay_id  ┆ first_careu ┆ last_careu ┆ intime     ┆ outtime    ┆ los      │
# │ ---        ┆ ---      ┆ ---      ┆ nit         ┆ nit        ┆ ---        ┆ ---        ┆ ---      │
# │ i64        ┆ i64      ┆ i64      ┆ ---         ┆ ---        ┆ str        ┆ str        ┆ f64      │
# │            ┆          ┆          ┆ str         ┆ str        ┆            ┆            ┆          │
# ╞════════════╪══════════╪══════════╪═════════════╪════════════╪════════════╪════════════╪══════════╡
# │ 10000032   ┆ 29079034 ┆ 39553978 ┆ Medical     ┆ Medical    ┆ 2180-07-23 ┆ 2180-07-23 ┆ 0.410266 │
# │            ┆          ┆          ┆ Intensive   ┆ Intensive  ┆ 14:00:00   ┆ 23:50:47   ┆          │
# │            ┆          ┆          ┆ Care Unit   ┆ Care Unit  ┆            ┆            ┆          │
# │            ┆          ┆          ┆ (M…         ┆ (M…        ┆            ┆            ┆          │
# │ 10000980   ┆ 26913865 ┆ 39765666 ┆ Medical     ┆ Medical    ┆ 2189-06-27 ┆ 2189-06-27 ┆ 0.497535 │
# │            ┆          ┆          ┆ Intensive   ┆ Intensive  ┆ 08:42:00   ┆ 20:38:27   ┆          │
# │            ┆          ┆          ┆ Care Unit   ┆ Care Unit  ┆            ┆            ┆          │
# │            ┆          ┆          ┆ (M…         ┆ (M…        ┆            ┆            ┆          │
# │ 10001217   ┆ 24597018 ┆ 37067082 ┆ Surgical    ┆ Surgical   ┆ 2157-11-20 ┆ 2157-11-21 ┆ 1.118032 │
# │            ┆          ┆          ┆ Intensive   ┆ Intensive  ┆ 19:18:02   ┆ 22:08:00   ┆          │
# │            ┆          ┆          ┆ Care Unit   ┆ Care Unit  ┆            ┆            ┆          │
# │            ┆          ┆          ┆ (…          ┆ (…         ┆            ┆            ┆          │
# │ 10001725   ┆ 25563031 ┆ 31205490 ┆ Medical/Sur ┆ Medical/Su ┆ 2110-04-11 ┆ 2110-04-12 ┆ 1.338588 │
# │            ┆          ┆          ┆ gical       ┆ rgical     ┆ 15:52:22   ┆ 23:59:56   ┆          │
# │            ┆          ┆          ┆ Intensive   ┆ Intensive  ┆            ┆            ┆          │
# │            ┆          ┆          ┆ Car…        ┆ Car…       ┆            ┆            ┆          │
# │ 10001884   ┆ 26184834 ┆ 37510196 ┆ Medical     ┆ Medical    ┆ 2131-01-11 ┆ 2131-01-20 ┆ 9.171817 │
# │            ┆          ┆          ┆ Intensive   ┆ Intensive  ┆ 04:20:05   ┆ 08:27:30   ┆          │
# │            ┆          ┆          ┆ Care Unit   ┆ Care Unit  ┆            ┆            ┆          │
# │            ┆          ┆          ┆ (M…         ┆ (M…        ┆            ┆            ┆          │
# │ …          ┆ …        ┆ …        ┆ …           ┆ …          ┆ …          ┆ …          ┆ …        │
# │ 19999442   ┆ 26785317 ┆ 32336619 ┆ Surgical    ┆ Surgical   ┆ 2148-11-19 ┆ 2148-11-26 ┆ 6.95037  │
# │            ┆          ┆          ┆ Intensive   ┆ Intensive  ┆ 14:23:43   ┆ 13:12:15   ┆          │
# │            ┆          ┆          ┆ Care Unit   ┆ Care Unit  ┆            ┆            ┆          │
# │            ┆          ┆          ┆ (…          ┆ (…         ┆            ┆            ┆          │
# │ 19999625   ┆ 25304202 ┆ 31070865 ┆ Medical/Sur ┆ Medical/Su ┆ 2139-10-10 ┆ 2139-10-11 ┆ 0.960741 │
# │            ┆          ┆          ┆ gical       ┆ rgical     ┆ 19:18:00   ┆ 18:21:28   ┆          │
# │            ┆          ┆          ┆ Intensive   ┆ Intensive  ┆            ┆            ┆          │
# │            ┆          ┆          ┆ Car…        ┆ Car…       ┆            ┆            ┆          │
# │ 19999828   ┆ 25744818 ┆ 36075953 ┆ Medical     ┆ Medical    ┆ 2149-01-08 ┆ 2149-01-10 ┆ 1.790995 │
# │            ┆          ┆          ┆ Intensive   ┆ Intensive  ┆ 18:12:00   ┆ 13:11:02   ┆          │
# │            ┆          ┆          ┆ Care Unit   ┆ Care Unit  ┆            ┆            ┆          │
# │            ┆          ┆          ┆ (M…         ┆ (M…        ┆            ┆            ┆          │
# │ 19999840   ┆ 21033226 ┆ 38978960 ┆ Trauma SICU ┆ Surgical   ┆ 2164-09-12 ┆ 2164-09-17 ┆ 5.297766 │
# │            ┆          ┆          ┆ (TSICU)     ┆ Intensive  ┆ 09:26:28   ┆ 16:35:15   ┆          │
# │            ┆          ┆          ┆             ┆ Care Unit  ┆            ┆            ┆          │
# │            ┆          ┆          ┆             ┆ (…         ┆            ┆            ┆          │
# │ 19999987   ┆ 23865745 ┆ 36195440 ┆ Trauma SICU ┆ Trauma     ┆ 2145-11-02 ┆ 2145-11-04 ┆ 1.937847 │
# │            ┆          ┆          ┆ (TSICU)     ┆ SICU       ┆ 22:59:00   ┆ 21:29:30   ┆          │
# │            ┆          ┆          ┆             ┆ (TSICU)    ┆            ┆            ┆          │
# └────────────┴──────────┴──────────┴─────────────┴────────────┴────────────┴────────────┴──────────┘

# %%
# %%time
icustays_pl.with_columns(
    pl.col("intime")
    .rank()
    .over("subject_id")
    .alias("rank")
).filter(pl.col("rank") == 1)
# Out:
# CPU times: user 111 ms, sys: 21.8 ms, total: 133 ms
# Wall time: 54 ms
# shape: (50_920, 9)
# ┌────────────┬──────────┬──────────┬─────────────┬───┬─────────────┬─────────────┬──────────┬──────┐
# │ subject_id ┆ hadm_id  ┆ stay_id  ┆ first_careu ┆ … ┆ intime      ┆ outtime     ┆ los      ┆ rank │
# │ ---        ┆ ---      ┆ ---      ┆ nit         ┆   ┆ ---         ┆ ---         ┆ ---      ┆ ---  │
# │ i64        ┆ i64      ┆ i64      ┆ ---         ┆   ┆ str         ┆ str         ┆ f64      ┆ f64  │
# │            ┆          ┆          ┆ str         ┆   ┆             ┆             ┆          ┆      │
# ╞════════════╪══════════╪══════════╪═════════════╪═══╪═════════════╪═════════════╪══════════╪══════╡
# │ 10000032   ┆ 29079034 ┆ 39553978 ┆ Medical     ┆ … ┆ 2180-07-23  ┆ 2180-07-23  ┆ 0.410266 ┆ 1.0  │
# │            ┆          ┆          ┆ Intensive   ┆   ┆ 14:00:00    ┆ 23:50:47    ┆          ┆      │
# │            ┆          ┆          ┆ Care Unit   ┆   ┆             ┆             ┆          ┆      │
# │            ┆          ┆          ┆ (M…         ┆   ┆             ┆             ┆          ┆      │
# │ 10000980   ┆ 26913865 ┆ 39765666 ┆ Medical     ┆ … ┆ 2189-06-27  ┆ 2189-06-27  ┆ 0.497535 ┆ 1.0  │
# │            ┆          ┆          ┆ Intensive   ┆   ┆ 08:42:00    ┆ 20:38:27    ┆          ┆      │
# │            ┆          ┆          ┆ Care Unit   ┆   ┆             ┆             ┆          ┆      │
# │            ┆          ┆          ┆ (M…         ┆   ┆             ┆             ┆          ┆      │
# │ 10001217   ┆ 24597018 ┆ 37067082 ┆ Surgical    ┆ … ┆ 2157-11-20  ┆ 2157-11-21  ┆ 1.118032 ┆ 1.0  │
# │            ┆          ┆          ┆ Intensive   ┆   ┆ 19:18:02    ┆ 22:08:00    ┆          ┆      │
# │            ┆          ┆          ┆ Care Unit   ┆   ┆             ┆             ┆          ┆      │
# │            ┆          ┆          ┆ (…          ┆   ┆             ┆             ┆          ┆      │
# │ 10001725   ┆ 25563031 ┆ 31205490 ┆ Medical/Sur ┆ … ┆ 2110-04-11  ┆ 2110-04-12  ┆ 1.338588 ┆ 1.0  │
# │            ┆          ┆          ┆ gical       ┆   ┆ 15:52:22    ┆ 23:59:56    ┆          ┆      │
# │            ┆          ┆          ┆ Intensive   ┆   ┆             ┆             ┆          ┆      │
# │            ┆          ┆          ┆ Car…        ┆   ┆             ┆             ┆          ┆      │
# │ 10001884   ┆ 26184834 ┆ 37510196 ┆ Medical     ┆ … ┆ 2131-01-11  ┆ 2131-01-20  ┆ 9.171817 ┆ 1.0  │
# │            ┆          ┆          ┆ Intensive   ┆   ┆ 04:20:05    ┆ 08:27:30    ┆          ┆      │
# │            ┆          ┆          ┆ Care Unit   ┆   ┆             ┆             ┆          ┆      │
# │            ┆          ┆          ┆ (M…         ┆   ┆             ┆             ┆          ┆      │
# │ …          ┆ …        ┆ …        ┆ …           ┆ … ┆ …           ┆ …           ┆ …        ┆ …    │
# │ 19999442   ┆ 26785317 ┆ 32336619 ┆ Surgical    ┆ … ┆ 2148-11-19  ┆ 2148-11-26  ┆ 6.95037  ┆ 1.0  │
# │            ┆          ┆          ┆ Intensive   ┆   ┆ 14:23:43    ┆ 13:12:15    ┆          ┆      │
# │            ┆          ┆          ┆ Care Unit   ┆   ┆             ┆             ┆          ┆      │
# │            ┆          ┆          ┆ (…          ┆   ┆             ┆             ┆          ┆      │
# │ 19999625   ┆ 25304202 ┆ 31070865 ┆ Medical/Sur ┆ … ┆ 2139-10-10  ┆ 2139-10-11  ┆ 0.960741 ┆ 1.0  │
# │            ┆          ┆          ┆ gical       ┆   ┆ 19:18:00    ┆ 18:21:28    ┆          ┆      │
# │            ┆          ┆          ┆ Intensive   ┆   ┆             ┆             ┆          ┆      │
# │            ┆          ┆          ┆ Car…        ┆   ┆             ┆             ┆          ┆      │
# │ 19999828   ┆ 25744818 ┆ 36075953 ┆ Medical     ┆ … ┆ 2149-01-08  ┆ 2149-01-10  ┆ 1.790995 ┆ 1.0  │
# │            ┆          ┆          ┆ Intensive   ┆   ┆ 18:12:00    ┆ 13:11:02    ┆          ┆      │
# │            ┆          ┆          ┆ Care Unit   ┆   ┆             ┆             ┆          ┆      │
# │            ┆          ┆          ┆ (M…         ┆   ┆             ┆             ┆          ┆      │
# │ 19999840   ┆ 21033226 ┆ 38978960 ┆ Trauma SICU ┆ … ┆ 2164-09-12  ┆ 2164-09-17  ┆ 5.297766 ┆ 1.0  │
# │            ┆          ┆          ┆ (TSICU)     ┆   ┆ 09:26:28    ┆ 16:35:15    ┆          ┆      │
# │ 19999987   ┆ 23865745 ┆ 36195440 ┆ Trauma SICU ┆ … ┆ 2145-11-02  ┆ 2145-11-04  ┆ 1.937847 ┆ 1.0  │
# │            ┆          ┆          ┆ (TSICU)     ┆   ┆ 22:59:00    ┆ 21:29:30    ┆          ┆      │
# └────────────┴──────────┴──────────┴─────────────┴───┴─────────────┴─────────────┴──────────┴──────┘

# %% [markdown]
# ## Web development (very quick intro)
#
# Plotly company has a basic web development tool called [`Dash`](https://dash.plotly.com/).
#
# The below is the very basics of it:

# %%
from dash import Dash, html, dcc, callback, Output, Input
import plotly.express as px
import pandas as pd

df = pd.read_csv('https://raw.githubusercontent.com/plotly/datasets/master/gapminder_unfiltered.csv')

app = Dash()

app.layout = [
    html.H1(children='Title of Dash App', style={'textAlign':'center'}),
    dcc.Dropdown(df.country.unique(), 'Canada', id='dropdown-selection'),
    dcc.Graph(id='graph-content')
]

@callback(
    Output('graph-content', 'figure'),
    Input('dropdown-selection', 'value')
)
def update_graph(value):
    dff = df[df.country==value]
    return px.line(dff, x='year', y='pop')

if __name__ == '__main__':
    app.run(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
